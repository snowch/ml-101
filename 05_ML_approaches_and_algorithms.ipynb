# %% [markdown]
# ### Introduction
#
# In this section we go deeper into the topics of machine learning models and approaches to machine learning.
#
# ### Questions
#
# Try to think of the answers to these questions before continuing.  The answers will be provided for you later, but it will help your memory if try to think them through yourself first.
#
#  1. What approach did we use to build the Iris model, e.g. Supervised Learning, Unsupervised Learning, Semi-supervised Learning?
#  2. Can you remember what type of machine learning algoritm (Classification, Clustering or Regression) we were did on the Iris dataset?
#  3. Can you remember what algorithm we used?
#
# ### Machine Learning Approaches
#
# Let's first understand a bit more about the different approaches to machine learning.  The common ones are Supervised Learning, Unsupervised Learning, Semi-supervised Learning.
#
# But what do they mean?  To keep things simple, let's focus on the first two:
#
# <div class="alert-info">
#
# ---
# _**DEFINITION: SUPERVISED LEARNING**_
#
# _Supervised learning is the processs of machine learning where data is provided to the agorithm that has one or more FEATURE values and one or more TARGET values._
#
# _In the Iris model, the first four column were the features and the last column was the target_
#
# | Sepal_Length | Sepal_Width | Petal_Length | Petal_Width | Class       |
# | -----------: | ----------: | -----------: | ----------: | ----------: |
# |          5.1 |         3.5 |          1.4 |         0.2 | Iris-setosa |
# |          ... |         ... |          ... |         ... | ... |
# |          5.9 |         3.0 |          5.1 |         1.8 | Iris-versicolor |
#
#
# _**DEFINITION: UNSUPERVISED LEARNING**_
#
# _Unsupervised learning is the processs of machine learning where data is provided to the agorithm that has one or more FEATURE values but no TARGET values._
#
# _Unsupervised learning learns patterns from untagged data.  For example, it may predict clusters of Iris flowers based on their FEATURE measurements._
#
# ---
# </div>
#
# ### Types of Machine Learning Algorithms
#
# Next we can explore types of Machine Learning Algorithms.  We will focus on just three:
#
# - Classification - this is a supervised approach that allows us to predict a class of object.
# - Regression - this is supervised approach that allows us to predict a value, e.g. the price of a house
# - Clustering - this is an un-supervised approach that allows us to cluster objects in groupings
#
# **Excercise 05.01** Navigate to Sckit-Learn's [homepage](https://scikit-learn.org/stable/) notice that the homepage provides easy navigation by Type of Machine Learning Algorithm.
#
# ### Machine Learning Algorithms
#
# <div class="alert-info">
#
# ---
# _**DEFINITION: MACHINE LEARNING ALGORITHMS**_
#
#
# _A machine learning algorithm is **the method** used to complete the job of building a model, such as the **Linear SVC** algorithm that we used to build the Iris Classification model._
#
# _**NOTE:** Machine Learning Algorithms are referred to as **ESTIMATORS** in Scikit-Learn_
#
# ---
# </div>

# %% [markdown]
# ### Navigation
#
# [Previous](./04_scikit_datasets.ipynb) | [Next](./06_Sckit-Learn_algorithm_cheetsheet.ipynb) notebook
