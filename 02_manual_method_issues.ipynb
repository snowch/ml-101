# %% [markdown]
# ### Introduction
#
# You got a phone call from your friend to excitedly tell you that she has added more data and two more columns to the dataset, "Sepal_Length" and "Sepal_Width". The columns "Sepal_Length", "Sepal_Width", "Petal_Length", "Petal_Width" are referred to as **features**.
#
# <div class="alert-info">
#
# ---
# _**DEFINITION: FEATURE**_
#
# _In machine learning and pattern recognition, a feature is an individual measurable property or characteristic of a phenomenon._
#
# *Source https://en.wikipedia.org/wiki/Feature_(machine_learning)*
#
# _You may also see FEATURE variables referred to as:_
#
# - _predictors_
# - _independent variables_
# - _experimental variables_
#
# ---
# </div>
#
# Let's explore the new dataset:

# %%
import pandas as pd

iris = pd.read_csv("data/iris.csv")

# let's peep at the first few records
iris.head()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width        Class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# now let's observe the last few records
iris.tail()
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width           Class
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %% [markdown]
# The field we are trying to predict with our machine learning model is the Class of Iris.  This is commonly referred to as the target variable.
#
# <div class="alert-info">
#
# ---
# _**DEFINITION: TARGET**_
#
# _The target variable is what you are trying to understand more about. We our previous example, we were trying to build a model that predicts the target value, i.e. the Class based on new measurements of new data._
#
# _You may also see TARGET variables referred to as:_
#
# - _dependent variable_
# - _outcome_
# - _outcome variable_
#
# ---
# </div>
#
#
# We can plot the dataset, this time we need more power than seaborn so we use matplotlib.
#
# You don't need to try to understand what this code is doing - matplotlib is very powerful (you can find whole courses dedicated to teaching it).

# %%
# Use matplotlib to give us more control over our plot
import matplotlib.pyplot as plt

# in particular we want a 3D plot
from mpl_toolkits.mplot3d import Axes3D

# create the plot
fig = plt.figure(figsize=(8, 6))
ax = Axes3D(fig, auto_add_to_figure=False)
fig.add_axes(ax) 

# plot our data
ax.scatter(
    iris['Sepal_Length'],
    iris['Sepal_Width'],
    iris['Petal_Length'],
    c=iris['Class'].map({ "Iris-setosa": 0, "Iris-versicolor": 1, "Iris-virginica": 2 }),
    cmap=plt.cm.Set1,
    edgecolor="k",
    s=40,
)
ax.set_title("Iris")
ax.set_xlabel("Sepal Length")
ax.set_ylabel("Sepal Width")
ax.set_zlabel("Petal Length")

plt.show()

# %% [markdown]
# Note that we can only plot three features but our dataset has four features.
#
# **Question**: How can we manually rebuild our model from the previous notebook if we can't even visualise all of the features?

# %% [markdown]
# ### Summary
#
# Our manual method of building a prediction model does not scale.  We need an alternative.
#
# While drinking our morning coffee, we start thinking ... _"What if the machine can learn the model from the data itself?"_
